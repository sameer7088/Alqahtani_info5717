# %%
# !pip install mysql-connector-python
# Out:
# Collecting mysql-connector-python
#   Downloading https://files.pythonhosted.org/packages/b0/d6/19f81615060d9a0eae204bd621fb5aa6604abc3fa45123583df029bd0895/mysql_connector_python-8.0.18-cp37-cp37m-macosx_10_13_x86_64.whl (4.5MB)
#     100% |████████████████████████████████| 4.5MB 2.3MB/s eta 0:00:01
# Collecting protobuf>=3.0.0 (from mysql-connector-python)
#   Downloading https://files.pythonhosted.org/packages/a5/c6/a8b6a74ab1e165f0aaa673a46f5c895af8780976880c98934ae82060356d/protobuf-3.10.0-cp37-cp37m-macosx_10_9_intel.whl (1.4MB)
#     100% |████████████████████████████████| 1.4MB 6.3MB/s eta 0:00:01
# Requirement already satisfied: setuptools in ./anaconda3/lib/python3.7/site-packages (from protobuf>=3.0.0->mysql-connector-python) (40.6.3)
# Requirement already satisfied: six>=1.9 in ./anaconda3/lib/python3.7/site-packages (from protobuf>=3.0.0->mysql-connector-python) (1.12.0)
# Installing collected packages: protobuf, mysql-connector-python
# Successfully installed mysql-connector-python-8.0.18 protobuf-3.10.0

# %%
# !pip install PyMySQL
# Out:
# Collecting PyMySQL
#   Downloading https://files.pythonhosted.org/packages/ed/39/15045ae46f2a123019aa968dfcba0396c161c20f855f11dea6796bcaae95/PyMySQL-0.9.3-py2.py3-none-any.whl (47kB)
#     100% |████████████████████████████████| 51kB 585kB/s ta 0:00:01
# Installing collected packages: PyMySQL
# Successfully installed PyMySQL-0.9.3

# %%
db_user = 'root'
db_password='1234AAA'
db_host='localhost'
db_database='afour'

import mysql.connector

# %%
def DBAdd (record):
    x = mysql.connector.connect(user = db_user, password = db_password,
                              host = db_host,
                              database = db_database)
    cursor = cnx.cursor()
    cursor.execute(record)
    x.commit()
    cursor.close()
    x.close()
    
def CreateUser(user_name, location, description, user_url,screen_name, follows, friends, statuses):
    description_clean = description.replace("'",'').strip()
    record = "INSERT INTO User (user_name, location, description, user_url,screen_name, follows, friends, statuses) VALUES ('" + user_name + "', '" + location + "', '" + description + "', '" + user_url + "', '" + screen_name + "', '" + follows + "', '" + friends + "', '" + statuses  + "')"
    DBAdd(record)

# %%
user_name = 'SSSaaff'
location = 'Denton'
description = 'User1'
user_url = 'www.google.com'
screen_name = 'mmss'
follows = '800'
friends = '500'
statuses = '4'

CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     199         try:
# --> 200             self._cmysql.connect(**cnx_kwargs)
#     201         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-107-cea48b2c4a79> in <module>
#       8 statuses = '4'
#       9
# ---> 10 CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
#
# <ipython-input-106-3ba9bf60e2ba> in CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
#      13     description_clean = description.replace("'",'').strip()
#      14     record = "INSERT INTO User (user_name, location, description, user_url,screen_name, follows, friends, statuses) VALUES ('" + user_name + "', '" + location + "', '" + description + "', '" + user_url + "', '" + screen_name + "', '" + follows + "', '" + friends + "', '" + statuses  + "')"
# ---> 15     DBAdd(record)
#
# <ipython-input-96-c125e6a2a09a> in DBAdd(record)
#       2     cnx = mysql.connector.connect(user = db_user, password = db_password,
#       3                               host = db_host,
# ----> 4                               database = db_database)
#       5     cursor = cnx.cursor()
#       6     cursor.execute(record)
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     174
#     175     if HAVE_CEXT and not use_pure:
# --> 176         return CMySQLConnection(*args, **kwargs)
#     177     return MySQLConnection(*args, **kwargs)
#     178 Connect = connect  # pylint: disable=C0103
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#      78
#      79         if kwargs:
# ---> 80             self.connect(**kwargs)
#      81
#      82     def _add_default_conn_attrs(self):
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#     779
#     780         self.disconnect()
# --> 781         self._open_connection()
#     782         # Server does not allow to run any other statement different from ALTER
#     783         # when user's password has been expired.
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     201         except MySQLInterfaceError as exc:
#     202             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 203                                              sqlstate=exc.sqlstate)
#     204         self._do_handshake()
#     205
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %%
import tweepy

consumer_key = "wXXXXXXXXXXXXXXXXXXXXXXX1"
consumer_secret = "qXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" 
access_token = "9XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXi"
access_token_secret = "kXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXT"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

user_list = ('deviel','quit01','lord1017','noway09','hay123','hbo','msn',
             'u&me','saudisguys','ydark','sam909')

for x in user_list:
    user = api.get_user(x)

    user_name = str(user.name)
    location = str(user.location)
    description = str(user.description)
    user_url = str(user.url)
    screen_name = str(user.screen_name)
    follows = str(user.followers_count)
    friends = str(user.friends_count)
    statuses = str(user.statuses_count)

    CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     199         try:
# --> 200             self._cmysql.connect(**cnx_kwargs)
#     201         except MySQLInterfaceError as exc:
#
# MySQLInterfaceError: Access denied for user 'root'@'localhost' (using password: YES)
#
# During handling of the above exception, another exception occurred:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-108-507554361e15> in <module>
#      27     statuses = str(user.statuses_count)
#      28
# ---> 29     CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
#
# <ipython-input-106-3ba9bf60e2ba> in CreateUser(user_name, location, description, user_url, screen_name, follows, friends, statuses)
#      13     description_clean = description.replace("'",'').strip()
#      14     record = "INSERT INTO User (user_name, location, description, user_url,screen_name, follows, friends, statuses) VALUES ('" + user_name + "', '" + location + "', '" + description + "', '" + user_url + "', '" + screen_name + "', '" + follows + "', '" + friends + "', '" + statuses  + "')"
# ---> 15     DBAdd(record)
#
# <ipython-input-96-c125e6a2a09a> in DBAdd(record)
#       2     cnx = mysql.connector.connect(user = db_user, password = db_password,
#       3                               host = db_host,
# ----> 4                               database = db_database)
#       5     cursor = cnx.cursor()
#       6     cursor.execute(record)
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     174
#     175     if HAVE_CEXT and not use_pure:
# --> 176         return CMySQLConnection(*args, **kwargs)
#     177     return MySQLConnection(*args, **kwargs)
#     178 Connect = connect  # pylint: disable=C0103
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in __init__(self, **kwargs)
#      78
#      79         if kwargs:
# ---> 80             self.connect(**kwargs)
#      81
#      82     def _add_default_conn_attrs(self):
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/abstracts.py in connect(self, **kwargs)
#     779
#     780         self.disconnect()
# --> 781         self._open_connection()
#     782         # Server does not allow to run any other statement different from ALTER
#     783         # when user's password has been expired.
#
# ~/anaconda3/lib/python3.7/site-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     201         except MySQLInterfaceError as exc:
#     202             raise errors.get_mysql_exception(msg=exc.msg, errno=exc.errno,
# --> 203                                              sqlstate=exc.sqlstate)
#     204         self._do_handshake()
#     205
#
# ProgrammingError: 1045 (28000): Access denied for user 'root'@'localhost' (using password: YES)

# %%
user_name = 'sam909'
follows_names = []
friends_names = []
users = tweepy.Cursor(api.followers, screen_name=user_name).items()

while True:
    try:
        user = next(users)
    except tweepy.TweepError:
        time.sleep(60*15)
        user = next(users)
    except StopIteration:
        break
    print ("@" + user.screen_name)
    follows_names.append(user.screen_name)
users = tweepy.Cursor(api.friends, screen_name=user_name).items()

while True:
    try:
        user = next(users)
    except tweepy.TweepError:
        time.sleep(60*15)
        user = next(users)
    except StopIteration:
        break
    print ("@" + user.screen_name)
    friends_names.append(user.screen_name)
# Out:
# @tsubasalukic341
# @DianaPurcellAz
# @hasanrasma
# @danawhite

# %%
import tweepy
import re
consumer_key = "wXXXXXXXXXXXXXXXXXXXXXXX1"
consumer_secret = "qXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX" 
access_token = "9XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXi"
access_token_secret = "kXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXT"
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

def get_tweets(a,count):
    tweets = []
    a=str(a)
    fetched_tweets = api.search(q = a, count = count)
    print(len(fetched_tweets))

    for tweet in fetched_tweets:
        parsed_tweet = {}
        parsed_tweet['text'] = tweet.text
        print(tweet.text+"\n")
    return tweets
tweets = get_tweets('texas weather',100)
# Out:
# 100
# NW Tarrant Co, Texas
# 22h | Current weather
#
# Wind: 4.0 mph
# Gust: 5.8 mph
# Temperature: 51.6 °F
# Humidity: 10 %
# Pressur… https://t.co/6jUGxfkTMM
#
# Texas de Brazil was amazing I just need to get in bed and sleep now, I’m not looking forward to go back to the cold weather in jersey
#
# RT @cvsherman: Bluebonnets and Lightning
# The Bluebonnet House in #MarbleFalls, #Texas with a #lightning #storm in the distance. Prints avai…
#
# @SamRouse15 you’re welcome. 😂 I wish is was cold already! We had like a week of cold weather then it went back to Texas weather 😂
#
# @MandaaMaranda Ugh shoot 🙄 thanks for giving me the tea on Texas weather rn 😂
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @PatrickVaughn4: A cold front, rain is forecast Friday followed by a great weekend.  Warm weather returns Monday ahead of a cold front l…
#
# A cold front, rain is forecast Friday followed by a great weekend.  Warm weather returns Monday ahead of a cold fro… https://t.co/DCqC4SLvaA
#
# @JacquelineVeloz @LEXXXLIEEE Update: we live in Texas and it’s sweater weather again
#
# Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. https://t.co/Vx8XCmyTtW
#
# RT @ScottFisherFOX7: Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/XCKz1mkUyu
#
# RT @ScottFisherFOX7: Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/cRMFctTBTr
#
# 📣 New Podcast! "Central Texas Weather Forecast November 22nd" on @Spreaker https://t.co/GZQkdwOOaJ
#
# Had to get a photo with this amazing group of young men after a good PT out in this great Texas weather... Always m… https://t.co/JjHjpUXCWC
#
# @rinstrids @astrotamer texas is cheap but it sucks and the weather goes from hot to cold in the blink of an eye THE… https://t.co/k9VixiySeQ
#
# Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/cRMFctTBTr
#
# Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/XCKz1mkUyu
#
# RT @NWSHouston: The @NWSSPC has placed portions of SE Texas, including the cities of Houston &amp; Galveston, under a marginal risk for severe…
#
# @nick_lindquist @EvanCooney0717 As a norther(western)er, I can totally attest to this phenomenon.
#
# Growing up in W… https://t.co/kzZPq8lFXt
#
# One of the things I hate the most is having a running nose. So annoyed with Texas' weather right now.
#
# Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. https://t.co/R5Phj07New
#
# AC back on. TEXAS WEATHER 🙄
#
# RT @DearmintCorey: People change like Texas weather these days.
#
# RT @jessejaureguito: @RozinaPittman @TDEM A1: Coming from California, we were always prepared for wildfire season and knew what we needed t…
#
# Dress up in #style for #Overcast #weather with a #winterhat in #Texas 👉 https://t.co/uWVc10HQFm ☁ #fashion
#
# RT @yazzylonglegs93: Texas weather is more confusing than relationships now a days
#
# AMA continues Winter Weather Advisory for Cimarron, Texas [OK] and Dallam, Hartley, Sherman [TX] till Nov 22, 6:00… https://t.co/RPNo8Fb875
#
# AMA continues Winter Weather Advisory for Cimarron, Texas [OK] and Dallam, Hartley, Sherman [TX] till Nov 22, 6:00… https://t.co/5ez2FdGIgH
#
# this Texas weather got me feeling like a moist towelette
#
# @mamabearparty Don’t take anything.. nothing in Texas is going to hold up to Colorado weather you need clothes from there to survive there 👍
#
# RT @milkteaure: so texas, i just wanna know.. when the fuck is the cold weather coming.. and STAYING?
#
# @RozinaPittman @TDEM A1: Coming from California, we were always prepared for wildfire season and knew what we neede… https://t.co/J4e1ixW49M
#
# RT @seaturtleweek: Cold-stunned Sea Turtles Rescued Along Texas Coast https://t.co/5lqYOhK4BJ https://t.co/ngeo8YN8t6
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @milkteaure: so texas, i just wanna know.. when the fuck is the cold weather coming.. and STAYING?
#
# @TxDOTAmarillo #FourSeasons is not just a hotel or a classical song, it is how we do #weather in 24 hours in the #Texas Panhandle.
#
# Cooler weather brought in a misting of rain in Downtown Plano. #fall #fallweather #planotx #plano #texas #leaves @… https://t.co/uREajzxLB3
#
# Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. https://t.co/JNTYXb5lJ1
#
# RT @ScottFisherFOX7: Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/zyOMfMcM40
#
# RT @ScottFisherFOX7: Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/nsKx2jjcNi
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# @ScottPadgettCBS @CBSDFW If the world had some ole coal mining stacks around THE ROCKWALL GARLAND CITY LINE (WHICH… https://t.co/y2h64HEQ64
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# so texas, i just wanna know.. when the fuck is the cold weather coming.. and STAYING?
#
# Hi so Texas weather is bullshit and I have not been able to wear my fluffy coat all week https://t.co/l0SIIzRIyz
#
# Austin = all the good things in Nashville + all the bad things in Portland + Texas weather and BBQ.
#
# oklahoma weather is worse than Texas weather...
#
# Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/nsKx2jjcNi
#
# Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/zyOMfMcM40
#
# RT @sosstandardbred: SYLVA KNOWS is the sweet girl that needs you next. Out in the lot with no shelter and the weather is getting colder. S…
#
# I think I talk about the weather with clients almost every single day. Most of them are in Texas or Florida so I get really depressed.
#
# Scott Fisher Says: Here's a look at the forecast wind direction for tomorrow. #Austin #Texas #Weather https://t.co/kma5o7M0ME
#
# Scott Fisher Says: 2 Days Worth of ATX Temps...All in One Chart! #Austin #Texas #Weather https://t.co/Rik4tDGb7E
#
# Fun fact... We have several small towns here in #NWOhioWx that are also states: New Hampshire (Auglaize County), Te… https://t.co/A8GT7L2iEP
#
# RT @riverrmann: #IAN1 #SFFBC
# 🤠
# Potatoes and green beans made it through the cold weather.
# 🙃
# The heavy rains will help them grow now.
# 😊
# Warm…
#
# RT @bgeologist: Corpus Christi Texas 21-Nov-19 Spraying the skank non-stop for 3 days #chemtrails #geoengineering weather #frequency NEXRAD…
#
# RT @AggieFootball: "Texas A&amp;M Football's identity..."
#
# This week, we look back at "The Wrecking Crew" of the 80's &amp; 90's.
#
# @pedersonsfarms…
#
# RT @ScottFisherFOX7: Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. htt…
#
# Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. https://t.co/cORXe8i7hA
#
# lovin’ my texas weather https://t.co/261kl1u7VW
#
# Deadass, Texas weather pisses me off. Driving to work, it was clear, than boom a heavy rain shower. Wtf
#
# was just getting into the shower and a scorpion crawls out of my towel and up my arm. i’m not sure moving to texas… https://t.co/KBVB9UNNGO
#
# RT @jackytxx: this is the type of weather we SHOULD’VE received all of October and November. Texas ain’t 💩.
#
# What are you thankful for today?  We are so thankful for Texas weather! #thankfulThursday https://t.co/ReDMNSjLqy
#
# RT @cvsherman: Bluebonnets and Lightning
# The Bluebonnet House in #MarbleFalls, #Texas with a #lightning #storm in the distance. Prints avai…
#
# Yazzy 0
# Texas weather 1
# I wore a dress and it’s pouring so now guess who is waiting in the car😒
#
# RT @yazzylonglegs93: Texas weather is more confusing than relationships now a days
#
# @BR54IA Hey Bim.
# Wow, rainy and dry! Texas weather sure is strange! 😆😆
# Wiper malfunctions are always fun! Had my sh… https://t.co/EhS3RMLPUn
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# RT @NWSHouston: The @NWSSPC has placed portions of SE Texas, including the cities of Houston &amp; Galveston, under a marginal risk for severe…
#
# Texas weather is more confusing than relationships now a days
#
# Right as I am getting over the last cool front. Texas weather is trying to get me fired on gawd https://t.co/yuMNemDzOk
#
# RT @PatrickVaughn4: Numerous showers/storms are forecast in SE Texas Friday Afternoon/Evening due to a cold front. The weekend forecast loo…
#
# Numerous showers/storms are forecast in SE Texas Friday Afternoon/Evening due to a cold front. The weekend forecast… https://t.co/B162mwXjfO
#
# @LoyalArgus That's why the MD told me to go to the naturopath.
#
# Fun fact: the further you get from the equator, th… https://t.co/Y52KlyloBI
#
# Texas fall is cold one minute and hot the next. ❄️ 🔥 The #trendingbeyondtypes boss babes are rocking great transiti… https://t.co/GGx89t1Ugf
#
# HELICAL VORTEX! Rope tornado roars in Northwest Texas on May 17, 2013 https://t.co/cSs274XWBD https://t.co/57cTpbpbRA
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# Scott Fisher Says: Up-To-Date Weather Info! Here's The Latest Regional Satellite &amp; Radar. #Austin #Texas #Weather. https://t.co/EEQu2Dx0ji
#
# RT @ScottFisherFOX7: Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/l0ahjB4DbL
#
# RT @ScottFisherFOX7: Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/lWFynpK6Fs
#
# We made it back into the middle 80s today, despite all the clouds in the area (about 10 degrees above average)!  Ne… https://t.co/l2MxRwPsEt
#
# current weather in Texas City: broken clouds, 74°F
# 88% humidity, wind 19mph, pressure 1015mb
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# Texas weather is gonna make us reschedule tomorrow night's gig :/
# Still set for the 5th in Sewell Park!
#
# Sorry gu… https://t.co/N7w4Y6uDnB
#
# @kk_in_AB Most of those rigs are enjoying the weather in Texas.
#
# @mistrustme1 @chewstroke Hoodie weather in Texas?
#
# the reason texas is fucked up is because of voter discouragement/suppression. Not the elections themselves.
# Also p… https://t.co/iH3c51nszM
#
# Scott Fisher Says: Lake Travis Cam! #laketravis #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/lWFynpK6Fs
#
# Scott Fisher Says: ATX Tower Cam! #Austin #Texas #Weather #ATXWeather #atxwx. https://t.co/l0ahjB4DbL
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# RT @breakingweather: A swath of drenching rain is forecast to push across a large part of the southern United States into the first part of…
#
# A swath of drenching rain is forecast to push across a large part of the southern United States into the first part… https://t.co/32oae6ljHy
#
# Sometimes, I laugh at my current situation then other days I just cry. That’s how the switch up of Texas weather is like..
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…
#
# RT @StormHour: Rainbow at Sunset over Austin, Texas by Christopher Sherman Photography @cvsherman ~ Weather Photography Favourites May 2019…

# %%
def get_tweets(a,count,date1,date2):
    tweets = []
    a=str(a)
    fetched_tweets = api.search(q = a, count = count, since = date1, until = date2)
    print(len(fetched_tweets))

    for tweet in fetched_tweets:
        parsed_tweet = {}
        parsed_tweet['text'] = tweet.text
        print(tweet.text+"\n")
    return tweets

tweets = get_tweets('#UNT',100,'2019-10-20','2019-10-27')
# Out:
# 0

# %%
def get_tweets(a,count,location):
    tweets = []
    a=str(a)
    fetched_tweets = api.search(q = a, count = count, geocode = location)
    print(len(fetched_tweets))

    for tweet in fetched_tweets:
        parsed_tweet = {}
        parsed_tweet['text'] = tweet.text
        print(tweet.text+"\n")
    return tweets

tweets = get_tweets('',100,'41.6702,-86.2532,10mi')
# Out:
# 100
# RT @PeteForAmerica: “We are going to have to unify a nation that is as divided as ever and, while doing it, address big issues that didn’t…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @PeteForAmerica: “We are going to have to unify a nation that is as divided as ever and, while doing it, address big issues that didn’t…
#
# RT @PeteButtigieg: Thank you for the warm welcome, Atlanta. Appreciated the opportunity to share what’s in my heart and to hear from Georgi…
#
# RT @PeteForAmerica: Are you keeping up with @PeteButtigieg’s day in Atlanta? Follow him on @Snapchat for the latest updates. https://t.co/z…
#
# RT @PeteForAmerica: “We are going to have to unify a nation that is as divided as ever and, while doing it, address big issues that didn’t…
#
# @commandantllyn clearly I am not cool enough to be one myself
#
# What a week! ♥️ https://t.co/yhpcCMaMj8
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# Need better receivers
#
# Signs of getting old:
#
# Making more noise getting up than you do getting off https://t.co/zHChkfxbC3
#
# Stop saying it. Just fucking do it, &amp; impress the people that doubted you.
#
# My word
#
# RT @AndrewMentock: At his radio show, Brian Kelly just said Chase Claypool has played with three dislocated fingers throughout the year, an…
#
# @SherbSmash and thats fine, not everyone will agree with me, but its just how the games make me feel :)
#
# RT @PeteForAmerica: “I'm not only running to defeat Donald Trump. I am running to prepare for the day that begins when Donald Trump has lef…
#
# Today... had been a long day. I just want to unwind
#
# RT @PeteForAmerica: 100 days until the South Carolina primary.
#
# 100 days to meet every voter in every community. https://t.co/iRwHGrsOhE
#
# RT @MunimSirry: Yg anda dukung itu bukan tuhan. Bisa berbuat salah dan boleh dikritik https://t.co/LmDl8vrAiZ
#
# RT @MunimSirry: Ingin tahu apa itu "radikalisme"? Saya usul pemerintah jangan gegabah dgn program deradikalisasi-nya. Jngn mudah anggap pah…
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @PeteForAmerica: 100 days until the South Carolina primary.
#
# 100 days to meet every voter in every community. https://t.co/iRwHGrsOhE
#
# @T_S_P_O_O_K_Y Well, they don’t have ‘Republicans’ like us in Bloody England, sooooo...
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @mp4mariano: @luisrodacot @vane_eguidazu Va pero a robar bien cabron
#
# Incredible. https://t.co/jbEa7N1y00
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# Miscommunication ruins everything when y’all hearts are still tied together.
#
# RT @PeteForAmerica: “I'm not only running to defeat Donald Trump. I am running to prepare for the day that begins when Donald Trump has lef…
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @PeteButtigieg: Thank you for the warm welcome, Atlanta. Appreciated the opportunity to share what’s in my heart and to hear from Georgi…
#
# RT @PeteForAmerica: “We are going to have to unify a nation that is as divided as ever and, while doing it, address big issues that didn’t…
#
# RT @shortyvoorde: Contributing to the development of Mayor Pete's disability policy was the honor of a lifetime. It opened my eyes to the i…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @G_Pond47: You are throwing out our Constitution so you can create your own set of Laws, @SpeakerPelosi @chuckschumer @realDonaldTrump a…
#
# RT @PeteForAmerica: No one should ever feel like a stranger in their own country.
#
# #DemDebate https://t.co/voKp5ve8rV
#
# RT @EHansenNDI: The end of the line for Notre Dame guard Trevor Ruhland feels more like a new beginning
#
# “I hope I’m remembered for a guy w…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# Me, when I go to Houston next month 😭🥰 https://t.co/r9RZ6r2QA8
#
# RT @PeteButtigieg: I’m not only running to defeat Donald Trump, I’m running to launch the era that must come next. I’m inviting progressive…
#
# Come on offense
#
# https://t.co/Brofpaz9cZ https://t.co/jLPOEuI61v
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# YIKES using a timeout when the clock is stopped and you're already losing.
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# Ugly in person lol https://t.co/uy5qbtxojU
#
# RT @mandy_pantz: As a resident of #SouthBend, and someone who was at the community gatherings after the Logan shooting... I can tell you th…
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# You are right on this one! He told this lie a few times before! https://t.co/s8QoDUnmwI
#
# RT @MunimSirry: Yg anda dukung itu bukan tuhan. Bisa berbuat salah dan boleh dikritik https://t.co/LmDl8vrAiZ
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# if you punt you're giving up.
#
# @devils4dvocate @na_dirs Saya berharap tulisan itu memunculkan diskusi serius, bukan tebak-tebakan
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @PeteForAmerica: That moment is coming. https://t.co/2xYaC3He6C
#
# Buttigieg vibes via /r/Pete_Buttigieg https://t.co/fwKhQPej9J #PeteForAmerica #Pete2020
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# @realDonaldTrump My gosh, @realDonaldTrump you are incredible.
# Don’t ever let up on these traitors.
#
# @gagefilmss my cashapp is $reminiisce if you wanna help me pay my bills
#
# RT @G_Pond47: You are throwing out our Constitution so you can create your own set of Laws, @SpeakerPelosi @chuckschumer @realDonaldTrump a…
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @Rodericka17: Here's what we're not about to do: take the high road and say we are never going to "engage in comparing struggles" and th…
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @arielle_moyee: - Now this was a beautiful moment to witness! She was so happy to meet Pete! She is an aspiring White House Corresponden…
#
# @ndhillis @PeteSampson_ ND own @jordancornette one of the best in the biz
#
# Yg anda dukung itu bukan tuhan. Bisa berbuat salah dan boleh dikritik https://t.co/LmDl8vrAiZ
#
# RT @Rodericka17: Playing oppression olympics isn't cute and does a disservice to both the Black and LGBTQ+ communities. ESPECIALLY folks th…
#
# RT @PeteForAmerica: People across the country submitted videos wishing @PeteButtigieg good luck. With a team like this, anything is possibl…
#
# RT @PeteForAmerica: No one should ever feel like a stranger in their own country.
#
# #DemDebate https://t.co/voKp5ve8rV
#
# RT @Rodericka17: To be abundantly clear here: Pete never has and never will minimize the Black American struggle by equating it to his pers…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# Boys really are some of the dumbest creatures on this earth
#
# RT @Rodericka17: Playing oppression olympics isn't cute and does a disservice to both the Black and LGBTQ+ communities. ESPECIALLY folks th…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @arielle_moyee: - And that’s a wrap Atlanta! 🙌🏽 Thank you Georgia for showing so much love. What a powerful week with a phenomenally tal…
#
# RT @Rodericka17: Here's what we're not about to do: take the high road and say we are never going to "engage in comparing struggles" and th…
#
# RT @PeteForAmerica: He won't be distracted.
#
# #DemDebate https://t.co/bnHJs2xKVx
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @breebroecker: @_gabriellahoy I love you
#
# RT @PeteForAmerica: It's time to bring America into the 21st century and that starts with taking our security seriously.
#
# #DemDebate https…
#
# @_cherub_111 We gonna come back and win this. It’s all good
#
# RT @Chas10Buttigieg: 🚨 Not a fundraising ask! 🚨
#
# Will you do me a favor? Pick a friend and send them a message of gratitude. Right now. Te…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# Here is my hope — this buzzer beating three pointer by @natelaszewski jump starts a sustained offensive run for thi… https://t.co/Pk6MNYMLmo
#
# @ShabanaMir1 Thank you for saying this. Been struggling w/ finding funding for my fieldwork for a while, and i need… https://t.co/aX48M6U6J2
#
# @zaiiirra Wait what what happened
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD
#
# RT @PeteButtigieg: Washington experience is not the only experience that matters. There’s more than 100 years of Washington experience on t…
#
# RT @ClayChurch: There's still time to help with our Tree of Love, and to help make a Merry Christmas for a child in Michiana. All you need…
#
# @AlexForPete @TheStefanSmith Is there any answer other than spotted cow? (Former Madison resident)
#
# RT @AJ_Indiana: My mayor and my city aren't perfect but we are better and looking forward to a promising future.
#
# RT @PeteForAmerica: Are you keeping up with @PeteButtigieg’s day in Atlanta? Follow him on @Snapchat for the latest updates. https://t.co/z…
#
# RT @AJ_Indiana: I bring the pride I have for my hometown, South Bend, and my Mayor @PeteButtigieg wherever I go even the democratic debates…
#
# RT @BobbiSalmon: @bguggs 🤣. He knows his words!  One thing I love about him, he speaks in cohesive sentences.
#
# I’m so exhausted..
#
# RT @PeteForAmerica: “We are going to have to unify a nation that is as divided as ever and, while doing it, address big issues that didn’t…
#
# RT @AJ_Indiana: In my 43 years, I've seen more positive change/progress in South  Bend over the last 8 years than in the previous 35. Pete'…
#
# RT @PeteForAmerica: The #DemDebate reviews are in! https://t.co/1zAvlFYYbD

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('assignment_4_property_tax_report_2019.csv')
dict = {}
for x in range(1900,2019):
    count = df.query('YEAR_BUILT == ' + str(x)).YEAR_BUILT.count()
    dict[x]=count

plt.plot(list(dict.keys()),list(dict.values()))
plt.title('Houses By Year')
    
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-7198740f5c73> in <module>
#      12     dict[x]=count
#      13
# ---> 14 plt.plot(list(dict.keys()),list(dict.values()))
#      15 plt.title('Houses By Year')
#      16
#
# TypeError: 'list' object is not callable

# %%
import numpy as np

n_bins = 25

fig, axs = plt.subplots(1)
axs.hist(list(dict.values()), bins=n_bins)
plt.title('Histogram of Houses By Year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-114-634a374920b9> in <module>
#       4
#       5 fig, axs = plt.subplots(1)
# ----> 6 axs.hist(list(dict.values()), bins=n_bins)
#       7 plt.title('Histogram of Houses By Year')
#       8 plt.show()
#
# TypeError: 'list' object is not callable

# %%
dict2 = {}
list = []
for x in df.ZONE_CATEGORY.unique():
    list.append(x)

for y in list:
    querylist = "ZONE_CATEGORY == '" + str(y) +"'"
    count = df.query(querylist).ZONE_CATEGORY.count()
    dict2[y]=count
fig1, ax1 = plt.subplots()
ax1.pie(dict2.values(), labels=dict2.keys(), autopct='%1.1f%%',
        shadow=False, startangle=0)
ax1.axis('equal')
plt.title('Houses by Zone Category')
plt.show()

# %%
plt.scatter(dict.keys(), dict.values(), s=5, alpha=0.5)
plt.title('Scatter Plot of Houses By Year')
plt.show()
